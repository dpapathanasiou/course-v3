# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# [PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/images'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/valid.txt'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/labels'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/codes.txt')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/images/Seq05VD_f03090.png'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/images/0006R0_f02430.png'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/images/0006R0_f01110.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/labels/0016E5_01650_P.png'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/labels/0016E5_01290_P.png'),
#  PosixPath('/notebooks/course-v3/nbs/dl1/data/camvid/labels/0016E5_01440_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           ...,
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17],
#           [19, 19, 19,  ..., 17, 17, 17]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 16266MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='69' class='' max='75', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       92.00% [69/75 01:02<00:05 4.5357]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.527956</td>
#       <td>0.927589</td>
#       <td>0.782412</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.965108</td>
#       <td>0.740628</td>
#       <td>0.809350</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.739804</td>
#       <td>0.525801</td>
#       <td>0.847278</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.665104</td>
#       <td>0.533664</td>
#       <td>0.857406</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.586337</td>
#       <td>0.534346</td>
#       <td>0.856384</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.595637</td>
#       <td>0.563372</td>
#       <td>0.861577</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.562831</td>
#       <td>0.449001</td>
#       <td>0.867289</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.520399</td>
#       <td>0.532947</td>
#       <td>0.869436</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.489598</td>
#       <td>0.405970</td>
#       <td>0.881097</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.427726</td>
#       <td>0.334143</td>
#       <td>0.902556</td>
#       <td>01:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=4, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.359514</td>
#       <td>0.309524</td>
#       <td>0.908446</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.353595</td>
#       <td>0.304076</td>
#       <td>0.910582</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.341740</td>
#       <td>0.305085</td>
#       <td>0.909535</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.330037</td>
#       <td>0.289731</td>
#       <td>0.915776</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.325528</td>
#       <td>0.290653</td>
#       <td>0.915863</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.321109</td>
#       <td>0.284355</td>
#       <td>0.921629</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.309159</td>
#       <td>0.293940</td>
#       <td>0.919831</td>
#       <td>01:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.301735</td>
#       <td>0.275622</td>
#       <td>0.920539</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.288073</td>
#       <td>0.261653</td>
#       <td>0.926139</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.280179</td>
#       <td>0.284378</td>
#       <td>0.918292</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.261027</td>
#       <td>0.265602</td>
#       <td>0.923381</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.242670</td>
#       <td>0.250233</td>
#       <td>0.928680</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=3, have 15781MB of GPU RAM free

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='61' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.50% [61/200 01:23<03:09 1.2730]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.343742</td>
#       <td>0.292692</td>
#       <td>0.921952</td>
#       <td>04:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.331947</td>
#       <td>0.335853</td>
#       <td>0.902451</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.317786</td>
#       <td>0.347052</td>
#       <td>0.898681</td>
#       <td>04:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.393858</td>
#       <td>0.318889</td>
#       <td>0.918280</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.394787</td>
#       <td>0.326490</td>
#       <td>0.912520</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.401561</td>
#       <td>0.294372</td>
#       <td>0.922852</td>
#       <td>04:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.403375</td>
#       <td>0.349308</td>
#       <td>0.910590</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.373647</td>
#       <td>0.334382</td>
#       <td>0.917542</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.322705</td>
#       <td>0.308716</td>
#       <td>0.923639</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.260660</td>
#       <td>0.252072</td>
#       <td>0.931353</td>
#       <td>04:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.234971</td>
#       <td>0.240628</td>
#       <td>0.933287</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.239878</td>
#       <td>0.256571</td>
#       <td>0.928319</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.221064</td>
#       <td>0.255186</td>
#       <td>0.929682</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.230751</td>
#       <td>0.245459</td>
#       <td>0.932161</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.218931</td>
#       <td>0.244519</td>
#       <td>0.931938</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.214481</td>
#       <td>0.252914</td>
#       <td>0.931023</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.189632</td>
#       <td>0.246949</td>
#       <td>0.933593</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.192577</td>
#       <td>0.249560</td>
#       <td>0.933403</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.191787</td>
#       <td>0.246027</td>
#       <td>0.934195</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.196910</td>
#       <td>0.249647</td>
#       <td>0.933887</td>
#       <td>04:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))

# %% [markdown]
# ## fin

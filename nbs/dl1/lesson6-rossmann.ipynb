# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.tabular import *

# %% [markdown]
# # Rossmann

# %% [markdown]
# ## Data preparation

# %% [markdown]
# To create the feature-engineered train_clean and test_clean from the Kaggle competition data, run `rossman_data_clean.ipynb`. One important step that deals with time series is this:
#
# ```python
# add_datepart(train, "Date", drop=False)
# add_datepart(test, "Date", drop=False)
# ```

# %%
path = Config().data_path()/'rossmann'
path
train_df = pd.read_pickle(path/'train_clean')

# %%
train_df.head().T
# Out:
#                                              0                    1  \
# index                                        0                    1
# Store                                        1                    2
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     5263                 6064
# Customers                                  555                  625
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    c                    a
# Assortment                                   a                    a
# CompetitionDistance                       1270                  570
# CompetitionOpenSinceMonth                    9                   11
# CompetitionOpenSinceYear                  2008                 2007
# Promo2                                       0                    1
# Promo2SinceWeek                              1                   13
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                 1015                 1017
# Max_VisibilityKm                            31                   10
# Mean_VisibilityKm                           15                   10
# Min_VisibilitykM                            10                   10
# Max_Wind_SpeedKm_h                          24                   14
# Mean_Wind_SpeedKm_h                         11                   11
# Max_Gust_SpeedKm_h                         NaN                  NaN
# Precipitationmm                              0                    0
# CloudCover                                   1                    4
# Events                                     Fog                  Fog
# WindDirDegrees                              13                  309
# StateName                               Hessen           Thueringen
# CompetitionOpenSince       2008-09-15 00:00:00  2007-11-15 00:00:00
# CompetitionDaysOpen                       2510                 2815
# CompetitionMonthsOpen                       24                   24
# Promo2Since                1900-01-01 00:00:00  2010-03-29 00:00:00
# Promo2Days                                   0                 1950
# Promo2Weeks                                  0                   25
# AfterSchoolHoliday                           0                    0
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                           57                   67
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             5                    5
# StateHoliday_bw                              0                    0
# Promo_bw                                     5                    5
# SchoolHoliday_fw                             7                    1
# StateHoliday_fw                              0                    0
# Promo_fw                                     5                    1
#
#                                              2                    3  \
# index                                        2                    3
# Store                                        3                    4
# DayOfWeek                                    5                    5
# Date                       2015-07-31 00:00:00  2015-07-31 00:00:00
# Sales                                     8314                13995
# Customers                                  821                 1498
# Open                                         1                    1
# Promo                                        1                    1
# StateHoliday                             False                False
# SchoolHoliday                                1                    1
# Year                                      2015                 2015
# Month                                        7                    7
# Week                                        31                   31
# Day                                         31                   31
# Dayofweek                                    4                    4
# Dayofyear                                  212                  212
# Is_month_end                              True                 True
# Is_month_start                           False                False
# Is_quarter_end                           False                False
# Is_quarter_start                         False                False
# Is_year_end                              False                False
# Is_year_start                            False                False
# Elapsed                             1438300800           1438300800
# StoreType                                    a                    c
# Assortment                                   a                    c
# CompetitionDistance                      14130                  620
# CompetitionOpenSinceMonth                   12                    9
# CompetitionOpenSinceYear                  2006                 2009
# Promo2                                       1                    0
# Promo2SinceWeek                             14                    1
# ...                                        ...                  ...
# Min_Sea_Level_PressurehPa                 1017                 1014
# Max_VisibilityKm                            31                   10
# Mean_VisibilityKm                           14                   10
# Min_VisibilitykM                            10                   10
# Max_Wind_SpeedKm_h                          14                   23
# Mean_Wind_SpeedKm_h                          5                   16
# Max_Gust_SpeedKm_h                         NaN                  NaN
# Precipitationmm                              0                    0
# CloudCover                                   2                    6
# Events                                     Fog                  NaN
# WindDirDegrees                             354                  282
# StateName                   NordrheinWestfalen               Berlin
# CompetitionOpenSince       2006-12-15 00:00:00  2009-09-15 00:00:00
# CompetitionDaysOpen                       3150                 2145
# CompetitionMonthsOpen                       24                   24
# Promo2Since                2011-04-04 00:00:00  1900-01-01 00:00:00
# Promo2Days                                1579                    0
# Promo2Weeks                                 25                    0
# AfterSchoolHoliday                           0                    0
# BeforeSchoolHoliday                          0                    0
# AfterStateHoliday                           57                   67
# BeforeStateHoliday                           0                    0
# AfterPromo                                   0                    0
# BeforePromo                                  0                    0
# SchoolHoliday_bw                             5                    5
# StateHoliday_bw                              0                    0
# Promo_bw                                     5                    5
# SchoolHoliday_fw                             5                    1
# StateHoliday_fw                              0                    0
# Promo_fw                                     5                    1
#
#                                              4
# index                                        4
# Store                                        5
# DayOfWeek                                    5
# Date                       2015-07-31 00:00:00
# Sales                                     4822
# Customers                                  559
# Open                                         1
# Promo                                        1
# StateHoliday                             False
# SchoolHoliday                                1
# Year                                      2015
# Month                                        7
# Week                                        31
# Day                                         31
# Dayofweek                                    4
# Dayofyear                                  212
# Is_month_end                              True
# Is_month_start                           False
# Is_quarter_end                           False
# Is_quarter_start                         False
# Is_year_end                              False
# Is_year_start                            False
# Elapsed                             1438300800
# StoreType                                    a
# Assortment                                   a
# CompetitionDistance                      29910
# CompetitionOpenSinceMonth                    4
# CompetitionOpenSinceYear                  2015
# Promo2                                       0
# Promo2SinceWeek                              1
# ...                                        ...
# Min_Sea_Level_PressurehPa                 1016
# Max_VisibilityKm                            10
# Mean_VisibilityKm                           10
# Min_VisibilitykM                            10
# Max_Wind_SpeedKm_h                          14
# Mean_Wind_SpeedKm_h                         11
# Max_Gust_SpeedKm_h                         NaN
# Precipitationmm                              0
# CloudCover                                   4
# Events                                     NaN
# WindDirDegrees                             290
# StateName                              Sachsen
# CompetitionOpenSince       2015-04-15 00:00:00
# CompetitionDaysOpen                        107
# CompetitionMonthsOpen                        3
# Promo2Since                1900-01-01 00:00:00
# Promo2Days                                   0
# Promo2Weeks                                  0
# AfterSchoolHoliday                           0
# BeforeSchoolHoliday                          0
# AfterStateHoliday                           57
# BeforeStateHoliday                           0
# AfterPromo                                   0
# BeforePromo                                  0
# SchoolHoliday_bw                             5
# StateHoliday_bw                              0
# Promo_bw                                     5
# SchoolHoliday_fw                             1
# StateHoliday_fw                              0
# Promo_fw                                     1
#
# [93 rows x 5 columns]

# %%
n = len(train_df); n
# Out:
# 844338

# %% [markdown]
# ### Experimenting with a sample

# %%
idx = np.random.permutation(range(n))[:2000]
idx.sort()
small_train_df = train_df.iloc[idx[:1000]]
small_test_df = train_df.iloc[idx[1000:]]
small_cont_vars = ['CompetitionDistance', 'Mean_Humidity']
small_cat_vars =  ['Store', 'DayOfWeek', 'PromoInterval']
small_train_df = small_train_df[small_cat_vars + small_cont_vars + ['Sales']]
small_test_df = small_test_df[small_cat_vars + small_cont_vars + ['Sales']]

# %%
small_train_df.head()
# Out:
#       Store  DayOfWeek    PromoInterval  CompetitionDistance  Mean_Humidity  \
# 1340    228          4  Feb,May,Aug,Nov              10800.0             73
# 1401    289          4              NaN               6540.0             56
# 1747    636          4  Jan,Apr,Jul,Oct                720.0             59
# 2103    993          4  Jan,Apr,Jul,Oct               3460.0             51
# 2516    291          3              NaN                  NaN             55
#
#       Sales
# 1340   9036
# 1401   6209
# 1747   9084
# 2103   9095
# 2516   8204

# %%
small_test_df.head()
# Out:
#         Store  DayOfWeek     PromoInterval  CompetitionDistance  \
# 387256    116          5               NaN                680.0
# 387695    555          5  Mar,Jun,Sept,Dec               1560.0
# 388532    278          4               NaN               9260.0
# 388790    536          4   Feb,May,Aug,Nov               4700.0
# 388913    659          4               NaN               1590.0
#
#         Mean_Humidity  Sales
# 387256             78   7778
# 387695             77   5624
# 388532             92   7395
# 388790             75   9794
# 388913             74   6599

# %%
categorify = Categorify(small_cat_vars, small_cont_vars)
categorify(small_train_df)
categorify(small_test_df, test=True)

# %%
small_test_df.head()
# Out:
#         Store DayOfWeek     PromoInterval  CompetitionDistance  Mean_Humidity  \
# 387256  116.0         5               NaN                680.0             78
# 387695    NaN         5  Mar,Jun,Sept,Dec               1560.0             77
# 388532  278.0         4               NaN               9260.0             92
# 388790  536.0         4   Feb,May,Aug,Nov               4700.0             75
# 388913  659.0         4               NaN               1590.0             74
#
#         Sales
# 387256   7778
# 387695   5624
# 388532   7395
# 388790   9794
# 388913   6599

# %%
small_train_df.PromoInterval.cat.categories
# Out:
# Index(['Feb,May,Aug,Nov', 'Jan,Apr,Jul,Oct', 'Mar,Jun,Sept,Dec'], dtype='object')

# %%
small_train_df['PromoInterval'].cat.codes[:5]
# Out:
# 1340    0
# 1401   -1
# 1747    1
# 2103    1
# 2516   -1
# dtype: int8

# %%
fill_missing = FillMissing(small_cat_vars, small_cont_vars)
fill_missing(small_train_df)
fill_missing(small_test_df, test=True)

# %%
small_train_df[small_train_df['CompetitionDistance_na'] == True]
# Out:
#        Store DayOfWeek    PromoInterval  CompetitionDistance  Mean_Humidity  \
# 2516     291         3              NaN               2730.0             55
# 113157   622         1              NaN               2730.0             82
# 125728   879         2  Feb,May,Aug,Nov               2730.0             59
# 166424   291         1              NaN               2730.0             77
# 341384   622         1              NaN               2730.0             88
# 384645   879         2  Feb,May,Aug,Nov               2730.0             79
#
#         Sales  CompetitionDistance_na
# 2516     8204                    True
# 113157   7043                    True
# 125728   3974                    True
# 166424  12377                    True
# 341384   6996                    True
# 384645   3013                    True

# %% [markdown]
# ### Preparing full data set

# %%
train_df = pd.read_pickle(path/'train_clean')
test_df = pd.read_pickle(path/'test_clean')

# %%
len(train_df),len(test_df)
# Out:
# (844338, 41088)

# %%
procs=[FillMissing, Categorify, Normalize]

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen',
    'Promo2Weeks', 'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear',
    'State', 'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_fw', 'StateHoliday_bw',
    'SchoolHoliday_fw', 'SchoolHoliday_bw']

cont_vars = ['CompetitionDistance', 'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday', 'BeforeStateHoliday', 'Promo', 'SchoolHoliday']

# %%
dep_var = 'Sales'
df = train_df[cat_vars + cont_vars + [dep_var,'Date']].copy()

# %%
test_df['Date'].min(), test_df['Date'].max()
# Out:
# (Timestamp('2015-08-01 00:00:00'), Timestamp('2015-09-17 00:00:00'))

# %%
cut = train_df['Date'][(train_df['Date'] == train_df['Date'][len(test_df)])].index.max()
cut
# Out:
# 41395

# %%
valid_idx = range(cut)

# %%
df[dep_var].head()
# Out:
# 0     5263
# 1     6064
# 2     8314
# 3    13995
# 4     4822
# Name: Sales, dtype: int64

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                .add_test(TabularList.from_df(test_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
doc(FloatList)

# %% [markdown]
# ## Model

# %%
max_log_y = np.log(np.max(train_df['Sales'])*1.2)
y_range = torch.tensor([0, max_log_y], device=defaults.device)

# %%
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=exp_rmspe)

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1116, 81)
#     (1): Embedding(8, 5)
#     (2): Embedding(4, 3)
#     (3): Embedding(13, 7)
#     (4): Embedding(32, 11)
#     (5): Embedding(3, 3)
#     (6): Embedding(26, 10)
#     (7): Embedding(27, 10)
#     (8): Embedding(5, 4)
#     (9): Embedding(4, 3)
#     (10): Embedding(4, 3)
#     (11): Embedding(24, 9)
#     (12): Embedding(9, 5)
#     (13): Embedding(13, 7)
#     (14): Embedding(53, 15)
#     (15): Embedding(22, 9)
#     (16): Embedding(7, 5)
#     (17): Embedding(7, 5)
#     (18): Embedding(4, 3)
#     (19): Embedding(4, 3)
#     (20): Embedding(9, 5)
#     (21): Embedding(9, 5)
#     (22): Embedding(3, 3)
#     (23): Embedding(3, 3)
#   )
#   (emb_drop): Dropout(p=0.04, inplace=False)
#   (bn_cont): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=233, out_features=1000, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001, inplace=False)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01, inplace=False)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
len(data.train_ds.cont_names)
# Out:
# 16

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>exp_rmspe</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='98' class='' max='12545', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.78% [98/12545 00:04<08:30 7.6303]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 1e-3, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>exp_rmspe</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.025498</td>
#       <td>0.021284</td>
#       <td>0.145066</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.018639</td>
#       <td>0.018985</td>
#       <td>0.129797</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.016397</td>
#       <td>0.017560</td>
#       <td>0.123354</td>
#       <td>03:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.013065</td>
#       <td>0.013037</td>
#       <td>0.110367</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.011084</td>
#       <td>0.011034</td>
#       <td>0.104732</td>
#       <td>03:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('1')

# %%
learn.recorder.plot_losses(skip_start=10000)

# %%
learn.load('1');

# %%
learn.fit_one_cycle(5, 3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>exp_rmspe</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.011586</td>
#       <td>0.015376</td>
#       <td>0.114467</td>
#       <td>03:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.012813</td>
#       <td>0.013664</td>
#       <td>0.111315</td>
#       <td>03:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011071</td>
#       <td>0.013302</td>
#       <td>0.112112</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.009849</td>
#       <td>0.012281</td>
#       <td>0.109771</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.010419</td>
#       <td>0.013771</td>
#       <td>0.112606</td>
#       <td>03:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5, 3e-4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>exp_rmspe</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.010330</td>
#       <td>0.013316</td>
#       <td>0.113705</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.011075</td>
#       <td>0.014589</td>
#       <td>0.122067</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011366</td>
#       <td>0.013988</td>
#       <td>0.116254</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.009592</td>
#       <td>0.015175</td>
#       <td>0.128578</td>
#       <td>03:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.008892</td>
#       <td>0.014844</td>
#       <td>0.129624</td>
#       <td>03:19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# (10th place in the competition was 0.108)

# %%
test_preds=learn.get_preds(DatasetType.Test)
test_df["Sales"]=np.exp(test_preds[0].data).numpy().T[0]
test_df[["Id","Sales"]]=test_df[["Id","Sales"]].astype("int")
test_df[["Id","Sales"]].to_csv("rossmann_submission.csv",index=False)
